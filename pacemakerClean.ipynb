# %%
import pandas as pd
import csv

# Load pacemaker_filtered (contains MDR_REPORT_KEYs of interest)
pacemaker_path = 'D:/DATA FOR RESEARCH PROJECT/pacemaker_filtered.csv'
pacemaker_df = pd.read_csv(pacemaker_path, dtype=str)
mdr_keys_set = set(pacemaker_df['MDR_REPORT_KEY'].dropna().unique())
print(f"🔍 Pacemaker report keys loaded: {len(mdr_keys_set)}")

# Setup paths and chunking
master_path = 'D:/DATA FOR RESEARCH PROJECT/Extracted files/mdrfoiThru2024.txt'
output_path = 'D:/DATA FOR RESEARCH PROJECT/master_pacemaker_matched.csv'
chunksize = 100000
write_header = True

# Process master file in chunks
chunk_iter = pd.read_csv(
    master_path,
    delimiter='|',
    encoding='latin1',
    dtype=str,
    engine='python',
    chunksize=chunksize,
    quoting=csv.QUOTE_NONE,
    on_bad_lines='skip'
)

for i, chunk in enumerate(chunk_iter):
    print(f"🔄 Processing chunk {i+1}...")

    # Filter only rows with matching MDR_REPORT_KEY
    filtered_chunk = chunk[chunk['MDR_REPORT_KEY'].isin(mdr_keys_set)]

    if not filtered_chunk.empty:
        filtered_chunk.to_csv(output_path, index=False, mode='a', header=write_header)
        write_header = False
        print(f"✅ Chunk {i+1}: {filtered_chunk.shape[0]} rows written")

print("🎉 Done filtering and writing matching master records!")
# Out:
# 🔍 Pacemaker report keys loaded: 282572
# 🔄 Processing chunk 1...
# 🔄 Processing chunk 2...
# 🔄 Processing chunk 3...
# 🔄 Processing chunk 4...
# 🔄 Processing chunk 5...
# 🔄 Processing chunk 6...
# 🔄 Processing chunk 7...
# 🔄 Processing chunk 8...
# 🔄 Processing chunk 9...
# 🔄 Processing chunk 10...
# 🔄 Processing chunk 11...
# 🔄 Processing chunk 12...
# 🔄 Processing chunk 13...
# 🔄 Processing chunk 14...
# 🔄 Processing chunk 15...
# 🔄 Processing chunk 16...
# 🔄 Processing chunk 17...
# 🔄 Processing chunk 18...
# 🔄 Processing chunk 19...
# 🔄 Processing chunk 20...
# 🔄 Processing chunk 21...
# 🔄 Processing chunk 22...
# 🔄 Processing chunk 23...
# 🔄 Processing chunk 24...
# 🔄 Processing chunk 25...
# 🔄 Processing chunk 26...
# 🔄 Processing chunk 27...
# ✅ Chunk 27: 1238 rows written
# 🔄 Processing chunk 28...
# ✅ Chunk 28: 2238 rows written
# 🔄 Processing chunk 29...
# ✅ Chunk 29: 2499 rows written
# 🔄 Processing chunk 30...
# ✅ Chunk 30: 2648 rows written
# 🔄 Processing chunk 31...
# ✅ Chunk 31: 2738 rows written
# 🔄 Processing chunk 32...
# ✅ Chunk 32: 2726 rows written
# 🔄 Processing chunk 33...
# ✅ Chunk 33: 2588 rows written
# 🔄 Processing chunk 34...
# ✅ Chunk 34: 2416 rows written
# 🔄 Processing chunk 35...
# ✅ Chunk 35: 2169 rows written
# 🔄 Processing chunk 36...
# ✅ Chunk 36: 13405 rows written
# 🔄 Processing chunk 37...
# ✅ Chunk 37: 2675 rows written
# 🔄 Processing chunk 38...
# ✅ Chunk 38: 2538 rows written
# 🔄 Processing chunk 39...
# ✅ Chunk 39: 2303 rows written
# 🔄 Processing chunk 40...
# ✅ Chunk 40: 2533 rows written
# 🔄 Processing chunk 41...
# ✅ Chunk 41: 2954 rows written
# 🔄 Processing chunk 42...
# ✅ Chunk 42: 2965 rows written
# 🔄 Processing chunk 43...
# ✅ Chunk 43: 2363 rows written
# 🔄 Processing chunk 44...
# ✅ Chunk 44: 2772 rows written
# 🔄 Processing chunk 45...
# ✅ Chunk 45: 2438 rows written
# 🔄 Processing chunk 46...
# ✅ Chunk 46: 2998 rows written
# 🔄 Processing chunk 47...
# ✅ Chunk 47: 3022 rows written
# 🔄 Processing chunk 48...
# ✅ Chunk 48: 2229 rows written
# 🔄 Processing chunk 49...
# ✅ Chunk 49: 2304 rows written
# 🔄 Processing chunk 50...
# ✅ Chunk 50: 2467 rows written
# 🔄 Processing chunk 51...
# ✅ Chunk 51: 2782 rows written
# 🔄 Processing chunk 52...
# ✅ Chunk 52: 3250 rows written
# 🔄 Processing chunk 53...
# ✅ Chunk 53: 3022 rows written
# 🔄 Processing chunk 54...
# ✅ Chunk 54: 3192 rows written
# 🔄 Processing chunk 55...
# ✅ Chunk 55: 2915 rows written
# 🔄 Processing chunk 56...
# ✅ Chunk 56: 3437 rows written
# 🔄 Processing chunk 57...
# ✅ Chunk 57: 2513 rows written
# 🔄 Processing chunk 58...
# ✅ Chunk 58: 2570 rows written
# 🔄 Processing chunk 59...
# ✅ Chunk 59: 2415 rows written
# 🔄 Processing chunk 60...
# ✅ Chunk 60: 2081 rows written
# 🔄 Processing chunk 61...
# ✅ Chunk 61: 2070 rows written
# 🔄 Processing chunk 62...
# ✅ Chunk 62: 1257 rows written
# 🔄 Processing chunk 63...
# ✅ Chunk 63: 1241 rows written
# 🔄 Processing chunk 64...
# ✅ Chunk 64: 1546 rows written
# 🔄 Processing chunk 65...
# ✅ Chunk 65: 1411 rows written
# 🔄 Processing chunk 66...
# ✅ Chunk 66: 2241 rows written
# 🔄 Processing chunk 67...
# ✅ Chunk 67: 1121 rows written
# 🔄 Processing chunk 68...
# ✅ Chunk 68: 1334 rows written
# 🔄 Processing chunk 69...
# ✅ Chunk 69: 1707 rows written
# 🔄 Processing chunk 70...
# ✅ Chunk 70: 2101 rows written
# 🔄 Processing chunk 71...
# ✅ Chunk 71: 1512 rows written
# 🔄 Processing chunk 72...
# ✅ Chunk 72: 1187 rows written
# 🔄 Processing chunk 73...
# ✅ Chunk 73: 897 rows written
# 🔄 Processing chunk 74...
# ✅ Chunk 74: 1390 rows written
# 🔄 Processing chunk 75...
# ✅ Chunk 75: 1272 rows written
# 🔄 Processing chunk 76...
# ✅ Chunk 76: 1578 rows written
# 🔄 Processing chunk 77...
# ✅ Chunk 77: 1610 rows written
# 🔄 Processing chunk 78...
# ✅ Chunk 78: 1578 rows written
# 🔄 Processing chunk 79...
# ✅ Chunk 79: 1535 rows written
# 🔄 Processing chunk 80...
# ✅ Chunk 80: 1774 rows written
# 🔄 Processing chunk 81...
# ✅ Chunk 81: 1957 rows written
# 🔄 Processing chunk 82...
# ✅ Chunk 82: 1876 rows written
# 🔄 Processing chunk 83...
# ✅ Chunk 83: 2238 rows written
# 🔄 Processing chunk 84...
# ✅ Chunk 84: 2651 rows written
# 🔄 Processing chunk 85...
# ✅ Chunk 85: 2966 rows written
# 🔄 Processing chunk 86...
# ✅ Chunk 86: 2589 rows written
# 🔄 Processing chunk 87...
# ✅ Chunk 87: 2171 rows written
# 🔄 Processing chunk 88...
# ✅ Chunk 88: 3148 rows written
# 🔄 Processing chunk 89...
# ✅ Chunk 89: 3170 rows written
# 🔄 Processing chunk 90...
# ✅ Chunk 90: 2970 rows written
# 🔄 Processing chunk 91...
# ✅ Chunk 91: 2179 rows written
# 🔄 Processing chunk 92...
# ✅ Chunk 92: 2370 rows written
# 🔄 Processing chunk 93...
# ✅ Chunk 93: 3106 rows written
# 🔄 Processing chunk 94...
# ✅ Chunk 94: 3932 rows written
# 🔄 Processing chunk 95...
# ✅ Chunk 95: 2852 rows written
# 🔄 Processing chunk 96...
# ✅ Chunk 96: 1582 rows written
# 🔄 Processing chunk 97...
# ✅ Chunk 97: 2383 rows written
# 🔄 Processing chunk 98...
# ✅ Chunk 98: 2720 rows written
# 🔄 Processing chunk 99...
# ✅ Chunk 99: 3342 rows written
# 🔄 Processing chunk 100...
# ✅ Chunk 100: 2891 rows written
# 🔄 Processing chunk 101...
# ✅ Chunk 101: 2501 rows written
# 🔄 Processing chunk 102...
# ✅ Chunk 102: 2395 rows written
# 🔄 Processing chunk 103...
# ✅ Chunk 103: 3386 rows written
# 🔄 Processing chunk 104...
# ✅ Chunk 104: 2946 rows written
# 🔄 Processing chunk 105...
# ✅ Chunk 105: 3229 rows written
# 🔄 Processing chunk 106...
# ✅ Chunk 106: 2953 rows written
# 🔄 Processing chunk 107...
# ✅ Chunk 107: 2819 rows written
# 🔄 Processing chunk 108...
# ✅ Chunk 108: 3538 rows written
# 🔄 Processing chunk 109...
# ✅ Chunk 109: 4127 rows written
# 🔄 Processing chunk 110...
# ✅ Chunk 110: 3119 rows written
# 🔄 Processing chunk 111...
# ✅ Chunk 111: 3982 rows written
# 🔄 Processing chunk 112...
# ✅ Chunk 112: 3956 rows written
# 🔄 Processing chunk 113...
# ✅ Chunk 113: 2686 rows written
# 🔄 Processing chunk 114...
# ✅ Chunk 114: 3076 rows written
# 🔄 Processing chunk 115...
# ✅ Chunk 115: 4790 rows written
# 🔄 Processing chunk 116...
# ✅ Chunk 116: 2969 rows written
# 🔄 Processing chunk 117...
# ✅ Chunk 117: 2586 rows written
# 🔄 Processing chunk 118...
# ✅ Chunk 118: 3637 rows written
# 🔄 Processing chunk 119...
# ✅ Chunk 119: 3987 rows written
# 🔄 Processing chunk 120...
# ✅ Chunk 120: 2681 rows written
# 🔄 Processing chunk 121...
# ✅ Chunk 121: 1862 rows written
# 🔄 Processing chunk 122...
# ✅ Chunk 122: 4759 rows written
# 🔄 Processing chunk 123...
# ✅ Chunk 123: 4257 rows written
# 🔄 Processing chunk 124...
# ✅ Chunk 124: 4305 rows written
# 🔄 Processing chunk 125...
# ✅ Chunk 125: 4202 rows written
# 🔄 Processing chunk 126...
# ✅ Chunk 126: 4754 rows written
# 🔄 Processing chunk 127...
# ✅ Chunk 127: 3913 rows written
# 🔄 Processing chunk 128...
# ✅ Chunk 128: 4977 rows written
# 🔄 Processing chunk 129...
# ✅ Chunk 129: 1322 rows written
# 🔄 Processing chunk 130...
# 🔄 Processing chunk 131...
# 🔄 Processing chunk 132...
# 🔄 Processing chunk 133...
# 🔄 Processing chunk 134...
# 🔄 Processing chunk 135...
# 🔄 Processing chunk 136...
# 🔄 Processing chunk 137...
# 🔄 Processing chunk 138...
# 🔄 Processing chunk 139...
# 🔄 Processing chunk 140...
# 🔄 Processing chunk 141...
# 🔄 Processing chunk 142...
# 🔄 Processing chunk 143...
# 🔄 Processing chunk 144...
# 🔄 Processing chunk 145...
# 🔄 Processing chunk 146...
# 🔄 Processing chunk 147...
# 🔄 Processing chunk 148...
# 🔄 Processing chunk 149...
# 🔄 Processing chunk 150...
# 🔄 Processing chunk 151...
# 🔄 Processing chunk 152...
# 🔄 Processing chunk 153...
# 🔄 Processing chunk 154...
# 🔄 Processing chunk 155...
# 🔄 Processing chunk 156...
# 🔄 Processing chunk 157...
# 🔄 Processing chunk 158...
# 🔄 Processing chunk 159...
# 🔄 Processing chunk 160...
# 🔄 Processing chunk 161...
# 🔄 Processing chunk 162...
# 🔄 Processing chunk 163...
# 🔄 Processing chunk 164...
# 🔄 Processing chunk 165...
# 🔄 Processing chunk 166...
# 🔄 Processing chunk 167...
# 🔄 Processing chunk 168...
# 🔄 Processing chunk 169...
# 🔄 Processing chunk 170...
# 🔄 Processing chunk 171...
# 🔄 Processing chunk 172...
# 🔄 Processing chunk 173...
# 🔄 Processing chunk 174...
# 🔄 Processing chunk 175...
# 🔄 Processing chunk 176...
# 🔄 Processing chunk 177...
# 🔄 Processing chunk 178...
# 🔄 Processing chunk 179...
# 🔄 Processing chunk 180...
# 🔄 Processing chunk 181...
# 🔄 Processing chunk 182...
# 🔄 Processing chunk 183...
# 🔄 Processing chunk 184...
# 🔄 Processing chunk 185...
# 🔄 Processing chunk 186...
# 🔄 Processing chunk 187...
# 🔄 Processing chunk 188...
# 🔄 Processing chunk 189...
# 🔄 Processing chunk 190...
# 🔄 Processing chunk 191...
# 🔄 Processing chunk 192...
# 🔄 Processing chunk 193...
# 🔄 Processing chunk 194...
# 🔄 Processing chunk 195...
# 🔄 Processing chunk 196...
# 🔄 Processing chunk 197...
# 🔄 Processing chunk 198...
# 🔄 Processing chunk 199...
# 🔄 Processing chunk 200...
# 🔄 Processing chunk 201...
# 🔄 Processing chunk 202...
# 🔄 Processing chunk 203...
# 🔄 Processing chunk 204...
# 🔄 Processing chunk 205...
# 🔄 Processing chunk 206...
# 🔄 Processing chunk 207...
# 🔄 Processing chunk 208...
# 🎉 Done filtering and writing matching master records!

# %%
import pandas as pd

# Load the two filtered datasets
pacemaker_df = pd.read_csv('D:/DATA FOR RESEARCH PROJECT/pacemaker_filtered.csv', dtype=str)
mdrfoitext_df = pd.read_csv('D:/DATA FOR RESEARCH PROJECT/master_pacemaker_matched.csv', dtype=str)

# Merge on MDR_REPORT_KEY
merged_df = pd.merge(pacemaker_df, mdrfoitext_df, on='MDR_REPORT_KEY', how='inner')

# Save final merged output
output_path = 'D:/DATA FOR RESEARCH PROJECT/final_pacemaker_merged.csv'
merged_df.to_csv(output_path, index=False)

print(f"Merged dataset shape: {merged_df.shape}")
print(f"Saved to: {output_path}")
# Out:
# Merged dataset shape: (713938, 119)
# Saved to: D:/DATA FOR RESEARCH PROJECT/final_pacemaker_merged.csv

# %%
import pandas as pd

# Load the merged file
new_path = 'D:/DATA FOR RESEARCH PROJECT/final_pacemaker_merged.csv'
new_df = pd.read_csv(new_path, dtype=str)

# Drop duplicates based on MDR_REPORT_KEY
deduped_df = new_df.drop_duplicates(subset='MDR_REPORT_KEY', keep='first')

# Save the cleaned file
cleaned_path = 'D:/DATA FOR RESEARCH PROJECT/final_pacemaker_merged_deduped.csv'
deduped_df.to_csv(cleaned_path, index=False)

print(f"✅ Deduplicated dataset shape: {deduped_df.shape}")
print(f"📁 Saved to: {cleaned_path}")
# Out:
# ✅ Deduplicated dataset shape: (282572, 119)
# 📁 Saved to: D:/DATA FOR RESEARCH PROJECT/final_pacemaker_merged_deduped.csv

# %%
import pandas as pd

# Load the uploaded file
file_path = 'D:/DATA FOR RESEARCH PROJECT/final_pacemaker_merged_deduped.csv'  
df = pd.read_csv(file_path, dtype=str)

# Drop all columns with only NaN values
df.dropna(axis=1, how='all', inplace=True)

# Drop all columns with only empty strings
df = df.loc[:, ~(df == '').all()]

# Drop DEVICE_SEQUENCE_NO column if it exists
if 'DEVICE_SEQUENCE_NO' in df.columns:
    df.drop(columns=['DEVICE_SEQUENCE_NO'], inplace=True)

# Preview cleaned DataFrame
print(f"Cleaned DataFrame shape: {df.shape}")
df.head()
# Out:
# Cleaned DataFrame shape: (282572, 92)
#   MDR_REPORT_KEY DATE_RECEIVED_x                          BRAND_NAME  \
# 0       16081313      2023/01/01                        ASSURITY MRI
# 1       16081360      2023/01/01  CAPSUREFIX NOVUS LEAD MRI SURESCAN
# 2       16081369      2023/01/01       CAPSUREFIX NOVUS MRI SURESCAN
# 3       16081371      2023/01/01                        ASSURITY MRI
# 4       16081384      2023/01/01                        ASSURITY MRI
#
#                             GENERIC_NAME                 MANUFACTURER_D_NAME  \
# 0  IMPLANTABLE PACEMAKER PULSE GENERATOR                              ABBOTT
# 1          PERMANENT PACEMAKER ELECTRODE      MEDTRONIC SINGAPORE OPERATIONS
# 2          PERMANENT PACEMAKER ELECTRODE      MEDTRONIC SINGAPORE OPERATIONS
# 3  IMPLANTABLE PACEMAKER PULSE GENERATOR  ST. JUDE MEDICAL, INC.(CRM-SYLMAR)
# 4  IMPLANTABLE PACEMAKER PULSE GENERATOR  ST. JUDE MEDICAL, INC.(CRM-SYLMAR)
#
#    MANUFACTURER_D_ADDRESS_1 MANUFACTURER_D_ADDRESS_2 MANUFACTURER_D_CITY  \
# 0   15900 VALLEY VIEW COURT                      NaN              SYLMAR
# 1  49 CHANGI SOUTH AVENUE 2       NASACO TECH CENTRE           SINGAPORE
# 2  49 CHANGI SOUTH AVENUE 2       NASACO TECH CENTRE           SINGAPORE
# 3   15900 VALLEY VIEW COURT                      NaN              SYLMAR
# 4   15900 VALLEY VIEW COURT                      NaN              SYLMAR
#
#   MANUFACTURER_D_STATE_CODE MANUFACTURER_D_ZIP_CODE  ...  SOURCE_TYPE  \
# 0                        CA                   91342  ...     01,05,07
# 1                       NaN                   48605  ...     01,05,07
# 2                       NaN                   48605  ...     01,05,07
# 3                        CA                   91342  ...  01,05,06,07
# 4                        CA                   91342  ...  01,05,06,07
#
#    DATE_ADDED DATE_CHANGED REPORTER_COUNTRY_CODE PMA_PMN_NUM EXEMPTION_NUMBER  \
# 0  01/01/2023   01/29/2024                    UK     P140033              NaN
# 1  01/01/2023   02/27/2024                    GM     P930039              NaN
# 2  01/01/2023   02/27/2024                    SW     P930039              NaN
# 3  01/01/2023   01/04/2023                    UK     P140033              NaN
# 4  01/01/2023   02/23/2023                    UK     P140033              NaN
#
#   SUMMARY_REPORT NOE_SUMMARIZED SUPPL_DATES_FDA_RECEIVED  \
# 0              N              1               02/06/2023
# 1              N              1               01/10/2023
# 2              N              1    01/03/2023;03/30/2023
# 3              N              1                      NaN
# 4              N              1               02/22/2023
#
#   SUPPL_DATES_MFR_RECEIVED
# 0               01/31/2023
# 1               01/09/2023
# 2    01/02/2023;03/23/2023
# 3                      NaN
# 4               02/07/2023
#
# [5 rows x 92 columns]

# %%
df.replace(['', ' ', 'NA', 'N/A', 'null', 'None'], pd.NA, inplace=True)
# standardizing missing values - so that they all can be treated the same

# %%
threshold = 0.90
df = df.loc[:, df.isnull().mean() < threshold]
# If a column has >90% missing values, it might not be useful.

# %%
df.shape
# Out:
# (282572, 77)

# %%
df.drop_duplicates(inplace=True)
df.shape  # okay, no dulicates. good - removed before at the time of joining
# Out:
# (282572, 77)

# %%
output_path = 'D:/DATA FOR RESEARCH PROJECT/Clean data/pacemaker_clean1.csv'
df.to_csv(output_path, index=False)

# %%
# imputation - imputing values in numerical columns and replacing them with the mean
# Identify numerical columns
numeric_cols = df.select_dtypes(include=['number']).columns

# Replace NaN values with the column mean
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Optional: check if any missing values remain
print("Missing values after imputation:\n", df[numeric_cols].isna().sum())

# Preview the dataset
df.head()
# Out:
# Missing values after imputation:
#  Series([], dtype: float64)
#   MDR_REPORT_KEY DATE_RECEIVED_x                          BRAND_NAME  \
# 0       16081313      2023/01/01                        ASSURITY MRI
# 1       16081360      2023/01/01  CAPSUREFIX NOVUS LEAD MRI SURESCAN
# 2       16081369      2023/01/01       CAPSUREFIX NOVUS MRI SURESCAN
# 3       16081371      2023/01/01                        ASSURITY MRI
# 4       16081384      2023/01/01                        ASSURITY MRI
#
#                             GENERIC_NAME                 MANUFACTURER_D_NAME  \
# 0  IMPLANTABLE PACEMAKER PULSE GENERATOR                              ABBOTT
# 1          PERMANENT PACEMAKER ELECTRODE      MEDTRONIC SINGAPORE OPERATIONS
# 2          PERMANENT PACEMAKER ELECTRODE      MEDTRONIC SINGAPORE OPERATIONS
# 3  IMPLANTABLE PACEMAKER PULSE GENERATOR  ST. JUDE MEDICAL, INC.(CRM-SYLMAR)
# 4  IMPLANTABLE PACEMAKER PULSE GENERATOR  ST. JUDE MEDICAL, INC.(CRM-SYLMAR)
#
#    MANUFACTURER_D_ADDRESS_1 MANUFACTURER_D_CITY MANUFACTURER_D_STATE_CODE  \
# 0   15900 VALLEY VIEW COURT              SYLMAR                        CA
# 1  49 CHANGI SOUTH AVENUE 2           SINGAPORE                       NaN
# 2  49 CHANGI SOUTH AVENUE 2           SINGAPORE                       NaN
# 3   15900 VALLEY VIEW COURT              SYLMAR                        CA
# 4   15900 VALLEY VIEW COURT              SYLMAR                        CA
#
#   MANUFACTURER_D_ZIP_CODE MANUFACTURER_D_COUNTRY_CODE  ... TYPE_OF_REPORT  \
# 0                   91342                          US  ...            I,F
# 1                   48605                          SN  ...            I,F
# 2                   48605                          SN  ...          I,F,F
# 3                   91342                          US  ...              I
# 4                   91342                          US  ...            I,F
#
#    SOURCE_TYPE  DATE_ADDED DATE_CHANGED REPORTER_COUNTRY_CODE PMA_PMN_NUM  \
# 0     01,05,07  01/01/2023   01/29/2024                    UK     P140033
# 1     01,05,07  01/01/2023   02/27/2024                    GM     P930039
# 2     01,05,07  01/01/2023   02/27/2024                    SW     P930039
# 3  01,05,06,07  01/01/2023   01/04/2023                    UK     P140033
# 4  01,05,06,07  01/01/2023   02/23/2023                    UK     P140033
#
#   SUMMARY_REPORT NOE_SUMMARIZED SUPPL_DATES_FDA_RECEIVED  \
# 0              N              1               02/06/2023
# 1              N              1               01/10/2023
# 2              N              1    01/03/2023;03/30/2023
# 3              N              1                      NaN
# 4              N              1               02/22/2023
#
#   SUPPL_DATES_MFR_RECEIVED
# 0               01/31/2023
# 1               01/09/2023
# 2    01/02/2023;03/23/2023
# 3                      NaN
# 4               02/07/2023
#
# [5 rows x 77 columns]

# %%
# check for nan values
# Check for missing values in the entire DataFrame
missing_values = df.isna().sum()

# Filter to show only columns with at least one missing value
missing_columns = missing_values[missing_values > 0]

if missing_columns.empty:
    print("No missing values found in the dataset!")
else:
    print("Columns with missing values:")
    print(missing_columns)
# Out:
# Columns with missing values:
# BRAND_NAME                     1497
# MANUFACTURER_D_NAME             118
# MANUFACTURER_D_ADDRESS_1      13600
# MANUFACTURER_D_CITY           13513
# MANUFACTURER_D_STATE_CODE     40538
#                               ...
# DATE_ADDED                      471
# REPORTER_COUNTRY_CODE         51784
# PMA_PMN_NUM                   21618
# SUPPL_DATES_FDA_RECEIVED     153307
# SUPPL_DATES_MFR_RECEIVED     153307
# Length: 61, dtype: int64

# %%
# Convert date columns (those that contain "date" in the name) to datetime
date_cols = [col for col in df.columns if "date" in col.lower()]
for col in date_cols:
    try:
        df[col] = pd.to_datetime(df[col], errors='coerce')
    except Exception as e:
        print(f"Could not convert {col} to datetime: {e}")

#df.head()

# %%
# Convert binary-like columns to booleans
for col in df.columns:
    unique_vals = set(df[col].dropna().unique())
    if unique_vals.issubset({'Y', 'N', 'y', 'n', '1', '0'}):
        df[col] = df[col].map({'Y': True, 'N': False, 'y': True, 'n': False, '1': True, '0': False})

# %%
# # There were multiple codes found for one field
# ## Formatting Fixes for Multi-Date and Multi-Code Fields
# import pandas as pd
# df = pd.read_csv(file_path, low_memory=False, dtype=str)

# # Step 1: Split semicolon-separated date fields into two new columns
# for col in ['SUPPL_DATES_FDA_RECEIVED', 'SUPPL_DATES_MFR_RECEIVED']:
#     df[[f"{col}_1", f"{col}_2"]] = df[col].str.split(';', expand=True)[[0, 1]]
#     df[f"{col}_1"] = pd.to_datetime(df[f"{col}_1"], errors='coerce')
#     df[f"{col}_2"] = pd.to_datetime(df[f"{col}_2"], errors='coerce')

# # Step 2: One-hot encode comma-separated multi-code columns
# def one_hot_multicodes(df, column_name, prefix):
#     col_list = df[column_name].dropna().apply(lambda x: x.split(','))
#     all_codes = pd.Series([item for sublist in col_list for item in sublist]).str.strip().unique()
#     for code in all_codes:
#         df[f"{prefix}_{code}"] = df[column_name].apply(lambda x: code in x.split(',') if pd.notnull(x) else False)
#     return df

# df = one_hot_multicodes(df, 'SOURCE_TYPE', 'SOURCE_TYPE')
# df = one_hot_multicodes(df, 'TYPE_OF_REPORT', 'TYPE_OF_REPORT')

# print("Multi-value fields split and one-hot encoded successfully.")
# print(df[[col for col in df.columns if "SUPPL_DATES" in col or "SOURCE_TYPE_" in col or "TYPE_OF_REPORT_" in col]].head())

# %%
df.shape
# Out:
# (282572, 77)

# %%
df.head()
# Out:
#   MDR_REPORT_KEY DATE_RECEIVED_x                          BRAND_NAME  \
# 0       16081313      2023-01-01                        ASSURITY MRI
# 1       16081360      2023-01-01  CAPSUREFIX NOVUS LEAD MRI SURESCAN
# 2       16081369      2023-01-01       CAPSUREFIX NOVUS MRI SURESCAN
# 3       16081371      2023-01-01                        ASSURITY MRI
# 4       16081384      2023-01-01                        ASSURITY MRI
#
#                             GENERIC_NAME                 MANUFACTURER_D_NAME  \
# 0  IMPLANTABLE PACEMAKER PULSE GENERATOR                              ABBOTT
# 1          PERMANENT PACEMAKER ELECTRODE      MEDTRONIC SINGAPORE OPERATIONS
# 2          PERMANENT PACEMAKER ELECTRODE      MEDTRONIC SINGAPORE OPERATIONS
# 3  IMPLANTABLE PACEMAKER PULSE GENERATOR  ST. JUDE MEDICAL, INC.(CRM-SYLMAR)
# 4  IMPLANTABLE PACEMAKER PULSE GENERATOR  ST. JUDE MEDICAL, INC.(CRM-SYLMAR)
#
#    MANUFACTURER_D_ADDRESS_1 MANUFACTURER_D_CITY MANUFACTURER_D_STATE_CODE  \
# 0   15900 VALLEY VIEW COURT              SYLMAR                        CA
# 1  49 CHANGI SOUTH AVENUE 2           SINGAPORE                       NaN
# 2  49 CHANGI SOUTH AVENUE 2           SINGAPORE                       NaN
# 3   15900 VALLEY VIEW COURT              SYLMAR                        CA
# 4   15900 VALLEY VIEW COURT              SYLMAR                        CA
#
#   MANUFACTURER_D_ZIP_CODE MANUFACTURER_D_COUNTRY_CODE  ... TYPE_OF_REPORT  \
# 0                   91342                          US  ...            I,F
# 1                   48605                          SN  ...            I,F
# 2                   48605                          SN  ...          I,F,F
# 3                   91342                          US  ...              I
# 4                   91342                          US  ...            I,F
#
#    SOURCE_TYPE DATE_ADDED DATE_CHANGED REPORTER_COUNTRY_CODE PMA_PMN_NUM  \
# 0     01,05,07 2023-01-01   2024-01-29                    UK     P140033
# 1     01,05,07 2023-01-01   2024-02-27                    GM     P930039
# 2     01,05,07 2023-01-01   2024-02-27                    SW     P930039
# 3  01,05,06,07 2023-01-01   2023-01-04                    UK     P140033
# 4  01,05,06,07 2023-01-01   2023-02-23                    UK     P140033
#
#   SUMMARY_REPORT NOE_SUMMARIZED SUPPL_DATES_FDA_RECEIVED  \
# 0          False              1               2023-02-06
# 1          False              1               2023-01-10
# 2          False              1                      NaT
# 3          False              1                      NaT
# 4          False              1               2023-02-22
#
#   SUPPL_DATES_MFR_RECEIVED
# 0               2023-01-31
# 1               2023-01-09
# 2                      NaT
# 3                      NaT
# 4               2023-02-07
#
# [5 rows x 77 columns]

# %%
pathClean = 'D:/DATA FOR RESEARCH PROJECT/Clean data/pacemakerClean2.csv'
df.to_csv(pathClean, index=False)
